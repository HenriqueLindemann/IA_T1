# %% [markdown]
# Imports e definição do dataset.

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# Carregamento do dataset cifar-10

# %% [markdown]
# O código abaixo mostra as 10 primeiras imagens de treino e teste do cifar-10

# %% [markdown]
# Abaixo, convertemos os rótulos escalares (números de 0 a 9) para one-hot encoding.
#
# Não é necessário realizar este passo, caso seja utilizada a função de custo esparse_categorical_cross_entropy

# %% [markdown]
# Função que retorna uma rede neural para o cifar-10

# %% [markdown]
# Trecho para treinar e avaliar a rede neural.
# O treino é realizado com os dados de treino e a avaliação do modelo é realizada nos dados de teste.

# %%
# Carregar o conjunto de dados CIFAR-10
cifar10 = keras.datasets.cifar10
#Carrega duas tuplas, representando os dados de treinamento e de teste.
#Cada tupla tem as imagens e os respectivos rótulos
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
num_classes = 10

# Defina as classes do CIFAR-10
class_names = ['Avião', 'Automóvel', 'Pássaro', 'Gato', 'Cervo',
               'Cachorro', 'Sapo', 'Cavalo', 'Navio', 'Caminhão']

# Crie um dicionário para mapear as classes para as imagens correspondentes
class_to_image = {}
for i in range(10):
    index = (test_labels == i).nonzero()[0][0]  # Encontre o primeiro índice da classe
    class_to_image[i] = test_images[index]

# Mostre uma imagem de cada classe
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.xticks([])  # Remova os rótulos do eixo x
    plt.yticks([])  # Remova os rótulos do eixo y
    plt.imshow(class_to_image[i])
    plt.xlabel(class_names[i])

plt.tight_layout()
plt.show()

# Converter para codificação one-hot dos labels
#train_labels = tf.keras.utils.to_categorical(train_labels, num_classes=num_classes)
#test_labels = tf.keras.utils.to_categorical(test_labels, num_classes=num_classes)
#Não é necessário se utilizar como função de custo esparse_categorical_cross_entropy

# %% [markdown]
# Na célula abaixo, adicione o código para carregar os demais datasets

# %%
import matplotlib.pyplot as plt
from tensorflow import keras

cifar100 = keras.datasets.cifar100

(x_train, y_train), (x_test, y_test) = cifar100.load_data()
n = 100  # número de classes

# Defina as classes do CIFAR-100
class_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'computer_keyboard', 'lamp', 'lawn_mower', 'leopard',
    'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree',
    'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea',
    'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider',
    'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank',
    'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip',
    'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

# Crie um dicionário para mapear as classes para as imagens correspondentes
class_to_image = {}
for i in range(100):
    index = (y_test == i).nonzero()[0][0]  # Encontre o primeiro índice da classe
    class_to_image[i] = x_test[index]

# Mostre uma imagem de cada classe
plt.figure(figsize=(20, 10))
for i in range(100):
    plt.subplot(10, 10, i + 1)
    plt.xticks([])  # Remova os rótulos do eixo x
    plt.yticks([])  # Remova os rótulos do eixo y
    plt.imshow(class_to_image[i])
    plt.xlabel(class_names[i])

plt.tight_layout()
plt.show()

# %%
mnist = keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
n = 10 #número de classes

plt.figure(figsize=(20, 4))
for i in range(n):
  # treino
  ax = plt.subplot(2, n, i + 1)
  plt.imshow(x_train[i])
  plt.title(f"treino, y={y_train[i]}")
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  # teste
  ax = plt.subplot(2, n, i + 1 + n)
  plt.imshow(x_test[i])
  plt.title(f"teste, y={y_test[i]}")
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
plt.show()

# %%
fashion_mnist = keras.datasets.fashion_mnist

(x_train, y_train),(x_test, y_test) = fashion_mnist.load_data()
n = 10 #number of classes

labels = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(20, 4))
for i in range(n):
  # training set
  ax = plt.subplot(2, n, i + 1)
  plt.imshow(x_train[i])
  plt.title(f"{labels[y_train[i]]}")
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  # test set
  ax = plt.subplot(2, n, i + 1 + n)
  plt.imshow(x_test[i])
  plt.title(f"{labels[y_test[i]]}")
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# Tarefa
# Escreva código para executar redes neurais nos seguintes datasets:
#
# MNIST (pode aproveitar o codigo existente)
# Fashion MNIST
# CIFAR-10
# CIFAR-100
# Cada execução deve ser por 10 épocas.
#
# Você deve preencher as funções a seguir para retornarem a rede neural com a melhor configuração que você conseguiu para cada dataset. O notebook deve ser entregue com a rede neural que obteve a melhor performance em cada conjunto de dados.
#
# IMPORTANTE: as funções não devem TREINAR nem AVALIAR as redes neurais, apenas instanciá-las e retorná-las.
#
# Ao final, preencha o dict results com o desempenho encontrado em cada execução.

# %%
def get_fashion_mnist_network():
  network = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28,28)),       # 1 input layer (flattening the 28x28 image into a one-dimensional vector)
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(n, activation='softmax') # 1 output layer with 10 neurons (1 per class). The variable n is already defined storing the number of classes
  ])

  network.compile(optimizer='adam',                        # optimizer
                loss='sparse_categorical_crossentropy',   # cross entropy adapted for multiple classes
                metrics=['accuracy'])                     # final performance metric (do not modify!)

  network.summary()

  return network

def get_mnist_network():
  network = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28,28)),       # 1 camada de entrada (achatando a entrada pra imagem 28x28 virar um vetor unidimensional)
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(n, activation='softmax') # 1 camada de saida com 10 neuronios (1 por classe). A variável n já definida armazena o número de classes
  ])

  network.compile(optimizer='adam',                        # otimizador
                loss='sparse_categorical_crossentropy',   # entropia cruzada adaptada para multiplas classes
                metrics=['accuracy'])                     # métrica final de desempenho (nao modifique!)

  network.summary()

  return network

def get_cifar100_network():
    model = keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),  # (32, 32, 3) because the images are 32X32 and RGB, therefore, having 3 color channels
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(n, activation='softmax')  # 100 output classes for CIFAR-100
    ])

    # Compile the model
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',  # can be replaced by sparse_categorical_cross_entropy
                  metrics=['accuracy'])

    model.summary()

    return model

#Você pode aproveitar as ideias do exemplo acima
def get_cifar10_network():
    model = keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),#(32, 32, 3) porque as imagens são 32X32 e RGB, portanto, tendo 3 canais de cor
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(num_classes, activation='softmax')  # 10 classes de saída
    ])

    # Compile o modelo
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',#pode ser substituída pela esparse_categorical_cross_entropy
                  metrics=['accuracy'])

    model.summary()

    return model

# %%
# Treine o modelo
model = get_cifar10_network()
model.fit(train_images, train_labels, epochs=10)

# Avalie o modelo no conjunto de teste
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f'Acurácia no conjunto de teste: {test_accuracy * 100:.2f}%')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_1 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 7200)              0
#
#  dense_2 (Dense)             (None, 64)                460864
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 462410 (1.76 MB)
# Trainable params: 462410 (1.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1563/1563 [==============================] - 37s 23ms/step - loss: 3.1771 - accuracy: 0.2411
# Epoch 2/10
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.7081 - accuracy: 0.3625
# Epoch 3/10
# 1563/1563 [==============================] - 38s 25ms/step - loss: 1.5644 - accuracy: 0.4159
# Epoch 4/10
# 1563/1563 [==============================] - 35s 22ms/step - loss: 1.4506 - accuracy: 0.4643
# Epoch 5/10
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3713 - accuracy: 0.4928
# Epoch 6/10
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3049 - accuracy: 0.5225
# Epoch 7/10
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.2550 - accuracy: 0.5429
# Epoch 8/10
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.2238 - accuracy: 0.5563
# Epoch 9/10
# 1563/1563 [==============================] - 37s 23ms/step - loss: 1.1931 - accuracy: 0.5650
# Epoch 10/10
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.1675 - accuracy: 0.5726
# 313/313 [==============================] - 4s 11ms/step - loss: 1.3881 - accuracy: 0.5224
# Acurácia no conjunto de teste: 52.24%

# %%
# Train the model
model = get_fashion_mnist_network()
model.fit(x_train, y_train, epochs=10)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Acurácia no conjunto de teste: {test_accuracy * 100:.2f}%')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 50)                39250
#
#  dense_3 (Dense)             (None, 10)                510
#
# =================================================================
# Total params: 39760 (155.31 KB)
# Trainable params: 39760 (155.31 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.6315 - accuracy: 0.5740
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.9518 - accuracy: 0.6407
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.8482 - accuracy: 0.6640
# Epoch 4/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.7125 - accuracy: 0.7152
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6702 - accuracy: 0.7301
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6501 - accuracy: 0.7341
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6484 - accuracy: 0.7386
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6367 - accuracy: 0.7407
# Epoch 9/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6273 - accuracy: 0.7425
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6256 - accuracy: 0.7442
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6656 - accuracy: 0.7312
# Acurácia no conjunto de teste: 73.12%

# %%
# Treine o modelo
model = get_mnist_network()
model.fit(x_train, y_train, epochs=10)

# Avalie o modelo no conjunto de teste
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Acurácia no conjunto de teste: {test_accuracy * 100:.2f}%')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_4 (Dense)             (None, 50)                39250
#
#  dense_5 (Dense)             (None, 10)                510
#
# =================================================================
# Total params: 39760 (155.31 KB)
# Trainable params: 39760 (155.31 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.8979 - accuracy: 0.7302
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5265 - accuracy: 0.8713
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3708 - accuracy: 0.9068
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2929 - accuracy: 0.9234
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2652 - accuracy: 0.9284
# 313/313 [==============================] - 1s 1ms/step - loss: 0.2975 - accuracy: 0.9274
# Acurácia no conjunto de teste: 92.74%

# %%
# Treine o modelo
model = get_cifar100_network()
model.fit(x_train, y_train, epochs=10)

# Avalie o modelo no conjunto de teste
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Acurácia no conjunto de teste: {test_accuracy * 100:.2f}%')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  flatten (Flatten)           (None, 7200)              0
#
#  dense (Dense)               (None, 64)                460864
#
#  dense_1 (Dense)             (None, 100)               6500
#
# =================================================================
# Total params: 468260 (1.79 MB)
# Trainable params: 468260 (1.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1563/1563 [==============================] - 37s 23ms/step - loss: 4.9848 - accuracy: 0.0125
# Epoch 2/10
# 1563/1563 [==============================] - 37s 23ms/step - loss: 4.5411 - accuracy: 0.0278
# Epoch 3/10
# 1563/1563 [==============================] - 35s 22ms/step - loss: 4.3755 - accuracy: 0.0525
# Epoch 4/10
# 1563/1563 [==============================] - 35s 22ms/step - loss: 4.2088 - accuracy: 0.0731
# Epoch 5/10
# 1563/1563 [==============================] - 36s 23ms/step - loss: 4.0482 - accuracy: 0.0909
# Epoch 6/10
# 1563/1563 [==============================] - 36s 23ms/step - loss: 3.8925 - accuracy: 0.1070
# Epoch 7/10
# 1563/1563 [==============================] - 35s 22ms/step - loss: 3.7813 - accuracy: 0.1222
# Epoch 8/10
# 1563/1563 [==============================] - 37s 24ms/step - loss: 3.6916 - accuracy: 0.1355
# Epoch 9/10
# 1563/1563 [==============================] - 36s 23ms/step - loss: 3.6117 - accuracy: 0.1473
# Epoch 10/10
# 1563/1563 [==============================] - 34s 22ms/step - loss: 3.5501 - accuracy: 0.1564
# 313/313 [==============================] - 4s 11ms/step - loss: 4.0215 - accuracy: 0.1117
# Acurácia no conjunto de teste: 11.17%

# %% [markdown]
# Preencha o dict abaixo substituindo os None com a acuracia final (acc) e o tempo de treinamento (time) encontrado no seu experimento pra cada dataset

# %%
results = {
    "mnist": {"time": None, "acc": None},
    "fashion_mnist": {"time": None, "acc": None},
    "cifar10": {"time": None, "acc": None},
    "cifar100": {"time": None, "acc": None},
}
